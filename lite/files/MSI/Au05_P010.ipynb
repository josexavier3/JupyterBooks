# %% [markdown]
# <img src="https://userweb.fct.unl.pt/~jmc.xavier/MSI/iLogos/nsst.jpg" width="400" height="100">
#
# # DEMI | NOVA SST
#
# ## Mecânica dos Sólidos I

# %% [markdown]
# # II. Análise de extensões. Extensometria. Equações da compatibilidade.
#
# ## Problema 10 <a name="PII510"></a>
#
# Admita o seguinte campo de deslocamentos de um objeto:
#
# \begin{equation}
# \vec{u} = k(x^2 + y) \vec\imath +
# k(y + z) \vec\jmath + k(x^2 + 2z^2) \vec{k}
# \end{equation}
#
# Determine a matriz do gradiente de deslocamentos.

# %% [markdown]
# ## Resolução
