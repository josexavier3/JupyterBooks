# %% [markdown]
# <img src="https://userweb.fct.unl.pt/~jmc.xavier/MSI/iLogos/nsst.jpg" width="400" height="100">
#
# # DEMI | NOVA SST
#
# ## Mecânica dos Sólidos I

# %% [markdown]
# ## Tração e compressão de barras elásticas e elastoplásticas perfeitas
# ## Vigas sujeitas à tracção/compressão. Parte III
# ## Problema 3 <a name="PIV103"></a>
#
# A figura representa uma barra rígida $ABC$ suportada por duas hastes $DA$ e $EB$, de secção uniforme com 38$\times$6 mm, e articulada em torno do ponto $C$. As hastes são feitas em aço macio, considerado um material elastoplástico com $E=$ 200 GPa e $\sigma_C$= 250 MPa. A intensidade da força $Q$ é progressivamente aumentada de zero a 225 KN e em seguida diminuída até zero. Sabendo que $a=$ 0.6 m, determine:
#
# [a)](#A) O deslocamento máximo que ocorre no ponto $B$ e o correspondente valor da tensão normal em cada haste.
#
# [b)](#B) O deslocamento residual no ponto $B$ e o valor das tensões residuais em cada haste.
#
# <img src="https://userweb.fct.unl.pt/~jmc.xavier/MSI/Notebooks/Au10/Au10_P003_i1.jpg"
# width="450">

# %% [markdown]
# ---
#
# Copyright (c) [Mecânica dos Sólidos I - DEMI - NOVA-SST]
#
# Interactive computing by <a href="https://jupyter.org/" target="_blank"> <span
# style="color:#333399"> Jupyter Notebook </span> </a> &nbsp;|&nbsp;Coded by <a href = "mailto: jmc.xavier@fct.unl.pt">José Xavier</a>
#
# Licensed under  <a href="http://creativecommons.org/licenses/by-sa/4.0/"
# target="_blank"> <span style="color:#333399;font-size: 20px"> CC BY-SA 4.0  </span></a>
