# %% [markdown]
# <img src="https://userweb.fct.unl.pt/~jmc.xavier/MSI/iLogos/nsst.jpg" width="400" height="100">
#
# # DEMI | NOVA SST
#
# ## Mecânica dos Sólidos I

# %% [markdown]
# ## Torção de barras elásticas
# ## Torção de barras elásticas. Parte II
# ## Problema 4 <a name="PV124"></a>
#
# Uma secção tubular, oca, de secção retangular 300$\times$100 mm (medidas exteriores), com espessura de 6 mm em três lados e espessura de 8 mm num dos lados maiores, está a ser sujeita à torção. Se a tensão tangencial máxima admissível for de 180 MPa, qual é o momento torsor máximo que podemos aplicar ao tubo e qual é o ângulo de rotação correspondente se o tubo tiver 8 m de comprimento.

# %%
from typing import NamedTuple

# Dados
# unidades: m, Pa, N
class dados(NamedTuple):
    N : float # kN
    T : float # kN.m
    dia : float  # m
    rho : float

d = dados(80, 15, 0.200, 0.080)

# %% [markdown]
# ---
#
# Copyright (c) [Mecânica dos Sólidos I - DEMI - NOVA-SST]
#
# Interactive computing by <a href="https://jupyter.org/" target="_blank"> <span
# style="color:#333399"> Jupyter Notebook </span> </a> &nbsp;|&nbsp;Coded by <a href = "mailto: jmc.xavier@fct.unl.pt">José Xavier</a>
#
# Licensed under  <a href="http://creativecommons.org/licenses/by-sa/4.0/"
# target="_blank"> <span style="color:#333399;font-size: 20px"> CC BY-SA 4.0  </span></a>
