# %% [markdown]
# <img src="https://userweb.fct.unl.pt/~jmc.xavier/MSI/iLogos/nsst.jpg" width="400" height="100">
#
# # DEMI | NOVA SST
#
# ## Mecânica dos Sólidos I

# %% [markdown]
# ## Tração e compressão de barras elásticas
# ## Vigas sujeitas à tracção/compressão. Parte I
# ## Problema 8 <a name="PIV8"></a>
#
# A barra rígida $ABD$ suporta uma carga distribuída uniforme $Q = 90$ kN/m e encontra-se apoiada num apoio fixo em $A$ e suspensa por dois cabos, $BC$ e $CD$, como indicado na figura. A área da secção transversal dos cabos é
# $A_\mathrm{secção} = 36$ mm$^2$ e o seu módulo de Young vale $E = 210$ GPa.
#
# [a)](#A) Determine as reações no apoio A e as forças suportadas pelos dois cabos.
#
# [b)](#B) Calcule o deslocamento vertical do ponto $D$.
#
# [c)](#C) Considerando que a tensão admissível do material utilizado para fabricar os cabos é $\sigma_\mathrm{adm}$ = 235 MPa, determine o valor mínimo da área da secção transversal que estes deverão apresentar para que essa tensão não seja excedida.
#
# <img src="https://userweb.fct.unl.pt/~jmc.xavier/MSI/Notebooks/Au08/Au08_P008_i1.jpg"
# width="350" height="240">

# %% [markdown]
# ## Resolução
#
# #### a) Determine as reações no apoio A e as forças suportadas pelos dois cabos.<a name="A"></a> ([enunciatum](#PIV89))

# %% [markdown]
# #### b) Calcule o deslocamento vertical do ponto $D$.<a name="B"></a> ([enunciatum](#PIV89))

# %% [markdown]
# #### c) Considerando que a tensão admissível do material utilizado para fabricar os cabos é $\sigma_\mathrm{adm}$ = 235 MPa, determine o valor mínimo da área da secção transversal que estes deverão apresentar para que essa tensão não seja excedida.<a name="C"></a> ([enunciatum](#PIV89))

# %% [markdown]
# ---
#
# Copyright (c) [Mecânica dos Sólidos I - DEMI - NOVA-SST]
#
# Interactive computing by <a href="https://jupyter.org/" target="_blank"> <span
# style="color:#333399"> Jupyter Notebook </span> </a> &nbsp;|&nbsp;Coded by <a href = "mailto: jmc.xavier@fct.unl.pt">José Xavier</a>
#
# Licensed under  <a href="http://creativecommons.org/licenses/by-sa/4.0/"
# target="_blank"> <span style="color:#333399;font-size: 20px"> CC BY-SA 4.0  </span></a>
