# %% [markdown]
# <img src="https://userweb.fct.unl.pt/~jmc.xavier/MSII/iLogos/logo_novafct.png" width="200">
#
# # Departamento de Engenharia Mecânica e Industrial
# ## Mecânica dos Sólidos II

# %% [markdown]
# ## Deslocamentos transversais de vigas
#
# ### Problema 6
#
# A viga ABCD está apoiada nos pontos B e D e suporta um momento em A, $M_A$, uma carga concentrada no ponto C, $F_C$, e uma carga distribuída, $Q(x)$, que varia linearmente entre B e C e é constante entre C e D como se mostra na figura.
#
# a) Utilizando funções de singularidade, escreva as equações do esforço transverso e do momento fletor na viga e trace os diagramas desses dois esforços.
#
# b) Determine a equação da linha elástica e obtenha o valor da flecha no ponto C em função do módulo de elasticidade, $E$, e do momento de inércia, $I$, da viga.
#
# <img src="https://userweb.fct.unl.pt/~jmc.xavier/MSII/Notebooks/Au08/P6/MSII_Au09_P6.png"
# style="max-width: 100%;"/>
# ### Resolução

# %% [markdown]
# ### Anexo: Funções de singularidade
#
# <img src="https://userweb.fct.unl.pt/~jmc.xavier/MSII/Notebooks/Formulario/singularity_functions.png"
# width="900">

# %% [markdown]
# ---
#
# Copyright (c) [Mecânica dos Sólidos I - DEMI - NOVA-SST]
#
# Interactive computing by <a href="https://jupyter.org/" target="_blank"> <span
# style="color:#333399"> Jupyter Notebook </span> </a> &nbsp;|&nbsp;Coded by <a href = "mailto: jmc.xavier@fct.unl.pt">José Xavier</a>
#
# Licensed under  <a href="http://creativecommons.org/licenses/by-sa/4.0/"
# target="_blank"> <span style="color:#333399;font-size: 20px"> CC BY-SA 4.0  </span></a>
