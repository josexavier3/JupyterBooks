# %% [markdown]
# <img src="https://userweb.fct.unl.pt/~jmc.xavier/MSII/iLogos/logo_novafct.png" style="width: 10%;"/>
#
# ## Mecânica dos Sólidos II

# %% [markdown]
# ## Métodos energéticos
#
# ### Problema 3
#
# A figura representa uma viga horizontal ABC ligada por uma articulação a um tirante vertical AD. A viga têm secção tubular, com diâmetro externo $\phi_e = 60$  mm e espessura de parede $t = 4$ mm. O tirante tem secção retangular com 12 $\times$ 6 mm. Ambas as peças são construídas em aço com $E = 210$ GPa. Sabendo que sobre a viga está aplicada uma carga distribuída uniforme entre A e C, como indicado, e que $Q_0 = 40$ N/m. Utilize o teorema de Castigliano para determinar o deslocamento vertical da viga no ponto C.
#
# <img src="https://userweb.fct.unl.pt/~jmc.xavier/MSII/Notebooks/Au11/P3/MSII_Au11_P3.png"
# style="width: 30%;"/>

# %% [markdown]
# ## Resolução
#
# - Cálculo das reações
#
# \begin{equation*}
# \sum F_x = 0
# \quad\wedge\quad
# \sum F_y = 0
# \quad\wedge\quad
# \sum M_A = 0
# \end{equation*}

# %%
import numpy as ny
import sympy as sy
from sympy.solvers import solve

QB: float = 20.e3 # unit N
AB: float = 4. # unit m
BC: float = 5.
E: float = 210.e9 # unit: N/m2
I: float = 577.e-6 # unit m⁴

ray, rdx, rdy, q, l = sy.symbols('rax ray rdy q l')

print('::: sistema de equações :::')
sumFX = rdx; print(f'sumFX :: {sumFX} = 0 [N]')
peq = q*l/2; print(f'Peq (triang.) = {peq} [N]')
sumFY = ray + rdy - q*l/2; print(f'sumFY :: {sumFY} = 0 [N]')
sumMA= rdy*l - peq*l/3; print(f'sumMA = {sumMA} [N.m]')
sol = solve([sumFX,sumFY,sumMA],[ray, rdx, rdy])

print('::: resolução :::')
RAy = sol[ray]; RAyn = RAy.subs([(q,QB),(l,BC)]); print(f'RAy = {RAy} = {RAyn*1e-3:.2f} [kN]')
RDx = sol[rdx]; RDxn = RDx.subs([(q,QB),(l,BC)]); print(f'RDx = {RDx} [kN]')
RDy = sol[rdy]; RDyn = RDy.subs([(q,QB),(l,BC)]); print(f'RDy = {RDy} = {RDyn*1e-3:.2f} [kN]')
# Out:
# ::: sistema de equações :::
# sumFX :: ray = 0 [N]
# Peq (triang.) = l*q/2 [N]
# sumFY :: -l*q/2 + rax + rdy = 0 [N]
# sumMA = -l**2*q/6 + l*rdy [N.m]
# ::: resolução :::
# RAy = l*q/3 = 33.33 [kN]
# RDx = 0 [kN]
# RDy = l*q/6 = 16.67 [kN]

# %% [markdown]
# ---
#
# Copyright (c) DEMI - FCT NOVA
#
# Interactive computing by <a href="https://jupyter.org/" target="_blank"> <span
# style="color:#333399"> Jupyter Notebook </span> </a> &nbsp;|&nbsp;Coded by <a href = "mailto: jmc.xavier@fct.unl.pt">José Xavier</a>
#
# Licensed under  <a href="http://creativecommons.org/licenses/by-sa/4.0/"
# target="_blank"> <span style="color:#333399;font-size: 20px"> CC BY-SA 4.0  </span></a>
