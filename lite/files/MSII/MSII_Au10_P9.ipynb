# %% [markdown]
# <img src="https://userweb.fct.unl.pt/~jmc.xavier/MSII/iLogos/logo_novafct.png" style="width: 30%;"/>
#
# ## Mecânica dos Sólidos II

# %% [markdown]
# ## Métodos energéticos
#
# ### Problema 9
#
# A figura representa uma viga horizontal, ABC, e outra vertical, AD, ligadas por uma articulação no ponto A. Ambas as vigas são contruídas em aço ($E=210$ GPa) com um perfil de secção quadrada com 40 $\times$ 40 mm. Considere uma carga distribuída que varia parabolicamente entre B e C, como indicado, sendo $Q_C = 60$ kN/m. Utilize o teorema de Castigliano para determinar a rotação da viga no ponto C.
#
# <img src="https://userweb.fct.unl.pt/~jmc.xavier/MSII/Notebooks/Au10/P9/MSII_Au10_P9.png"
# style="width: 40%;"/>

# %% [markdown]
# ---
#
# Copyright (c) DEMI - FCT NOVA
#
# Interactive computing by <a href="https://jupyter.org/" target="_blank"> <span
# style="color:#333399"> Jupyter Notebook </span> </a> &nbsp;|&nbsp;Coded by <a href = "mailto: jmc.xavier@fct.unl.pt">José Xavier</a>
#
# Licensed under  <a href="http://creativecommons.org/licenses/by-sa/4.0/"
# target="_blank"> <span style="color:#333399;font-size: 20px"> CC BY-SA 4.0  </span></a>
