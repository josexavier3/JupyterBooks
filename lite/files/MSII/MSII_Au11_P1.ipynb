# %% [markdown]
# <img src="https://userweb.fct.unl.pt/~jmc.xavier/MSII/iLogos/logo_novafct.png" style="width: 10%;"/>
#
# ## Mecânica dos Sólidos II

# %% [markdown]
# ## Métodos energéticos
#
# ### Problema 1
#
# A figura representa um pórtico constituído por duas vigas verticais AB e CD e uma viga horizontal BC. O carregamento aplicado consiste numa carga distribuída uniforme aplicada entre A e B. Considere que as vigas têm módulo de elasticidade $E = 210$ GPa e momento de inércia $I = 4,5 \times 10^3$ m$^4$ e que $Q_0 = 30$ kN/m e determine utilizando o teorema de Castigliano o deslocamento horizontal no ponto A.
#
# <img src="https://userweb.fct.unl.pt/~jmc.xavier/MSII/Notebooks/Au11/P1/MSII_Au11_P1.png"
# style="width: 30%;"/>

# %% [markdown]
# ## Resolução
#
# - Cálculo das reações
#
# \begin{equation*}
# \sum F_x = 0
# \quad\wedge\quad
# \sum F_y = 0
# \quad\wedge\quad
# \sum M_A = 0
# \end{equation*}

# %%
import numpy as ny
import sympy as sy
from sympy.solvers import solve

QB = 20.e3 # unit N
AB, BC = 4., 5. # unit m
E = 210.e9 # unit: N/m2
I = 577.e-6 # unit m⁴

ray, rdx, rdy, q, l = sy.symbols('rax ray rdy q l')

print('::: sistema de equações :::')
sumFX = rdx; print(f'{sumFX = } = 0 [N]')
peq = q*l/2; print(f'Peq (triang.) = {peq} [N]')
sumFY = ray + rdy - q*l/2; print(f'{sumFY = } = 0 [N]')
sumMA= rdy*l - peq*l/3; print(f'{sumMA = } [N.m]')
sol = solve([sumFX,sumFY,sumMA],[ray, rdx, rdy])

print('::: resolução :::')
print(sol)
RAy = sol[ray]; RAyn = RAy.subs([(q,QB),(l,BC)]); print(f'RAy = {RAy} = {RAyn*1e-3:.2f} [kN]')
RDx = sol[rdx]; RDxn = RDx.subs([(q,QB),(l,BC)]); print(f'RDx = {RDx} [kN]')
RDy = sol[rdy]; RDyn = RDy.subs([(q,QB),(l,BC)]); print(f'RDy = {RDy} = {RDyn*1e-3:.2f} [kN]')
# Out:
# ::: sistema de equações :::
# sumFX = ray = 0 [N]
# Peq (triang.) = l*q/2 [N]
# sumFY = -l*q/2 + rax + rdy = 0 [N]
# sumMA = -l**2*q/6 + l*rdy [N.m]
# ::: resolução :::
# {rax: l*q/3, ray: 0, rdy: l*q/6}
# RAy = l*q/3 = 33.33 [kN]
# RDx = 0 [kN]
# RDy = l*q/6 = 16.67 [kN]

# %% [markdown]
# ---
#
# Copyright (c) DEMI - FCT NOVA
#
# Interactive computing by <a href="https://jupyter.org/" target="_blank"> <span
# style="color:#333399"> Jupyter Notebook </span> </a> &nbsp;|&nbsp;Coded by <a href = "mailto: jmc.xavier@fct.unl.pt">José Xavier</a>
#
# Licensed under  <a href="http://creativecommons.org/licenses/by-sa/4.0/"
# target="_blank"> <span style="color:#333399;font-size: 20px"> CC BY-SA 4.0  </span></a>
