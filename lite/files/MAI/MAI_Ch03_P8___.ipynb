# %% [markdown]
# <img src="https://userweb.fct.unl.pt/~jmc.xavier/MAI/iLogos/logo_novafct.png" width="200">
#
# # Departamento de Engenharia Mecânica e Industrial
# ## Mecânica Aplicada I

# %% [markdown]
# ## EQUILÍBRIO DO CORPO RÍGIDO NO PLANO. ATRITO.
#
# ***
# #### Problema 8
#
# Considere um cilindro homogéneo com 30 kg de massa e raio 200 mm que se encontra em repouso, sendo suportado por uma superfície inclinada em A e por outra vertical em B, como mostra a figura. Se o coeficiente de atrito estático entre o cilindro e as superfícies é de 0,30, calcule o binário $M$ aplicado ao cilindro necessário para causar o escorregamento do mesmo.
#
# <img src="https://drive.google.com/uc?id=1-SwRu4tYyZCE1bUm0N42YwtMN7WSmPCy"
# style="max-width: 100%;"/>
# ***
# #### Resolução

# %% [markdown]
# ---
#
# Copyright (c) DEMI - FCT NOVA
#
# Interactive computing by <a href="https://jupyter.org/" target="_blank"> <span
# style="color:#333399"> Jupyter Notebook </span> </a> &nbsp;|&nbsp;Coded by <a href = "mailto: jmc.xavier@fct.unl.pt">José Xavier</a>
#
# Licensed under  <a href="http://creativecommons.org/licenses/by-sa/4.0/"
# target="_blank"> <span style="color:#333399;font-size: 20px"> CC BY-SA 4.0  </span></a>
