# %% [markdown]
# <img src="https://userweb.fct.unl.pt/~jmc.xavier/MAI/iLogos/logo_novafct.png" width="200">
#
# # Departamento de Engenharia Mecânica e Industrial
# ## Mecânica Aplicada I

# %% [markdown]
# ## EQUILÍBRIO DA PARTÍCULA NO ESPAÇO
#
# ***
# #### Problema 15
#
# A placa homogénea ABCD de massa m está apoiada em duas dobradiças colocadas na aresta AB e no cabo EF.
#
# a)	Sabendo que a dobradiça B não tem componente axial na força de reacção, represente o diagrama de corpo livre da placa ABCD.
#
# b)	Determine o sistema de equações de equilíbrio da placa ABCD.
#
# c)	Sabendo que o momento da força do cabo em relação à aresta AB da placa é de 98,1 N$\cdot$m no sentido negativo, determine a intensidade da força $\vec{T}$ neste e a massa m da placa.
#
# <img src="https://drive.google.com/uc?id=1lg8Kb-oZX9cgiNsYv8F-ESTwlpC5tBvi"
# style="max-width: 100%;"/>
# ***
#
# #### Resolução

# %% [markdown]
# ---
#
# Copyright (c) DEMI - FCT NOVA
#
# Interactive computing by <a href="https://jupyter.org/" target="_blank"> <span
# style="color:#333399"> Jupyter Notebook </span> </a> &nbsp;|&nbsp;Coded by <a href = "mailto: jmc.xavier@fct.unl.pt">José Xavier</a>
#
# Licensed under  <a href="http://creativecommons.org/licenses/by-sa/4.0/"
# target="_blank"> <span style="color:#333399;font-size: 20px"> CC BY-SA 4.0  </span></a>
