# %% [markdown]
# <img src="https://userweb.fct.unl.pt/~jmc.xavier/MAI/iLogos/logo_novafct.png" width="200">
#
# # Departamento de Engenharia Mecânica e Industrial
# ## Mecânica Aplicada I

# %% [markdown]
# ## MOMENTO DE 2ª ORDEM DE UMA SUPERFÍCIE. MOMENTO DE INÉRCIA DE UM CORPO.
#
# ### Problema 2
#
# A figura representa a secção transversal de uma viga, que foi obtida ligando uma barra de secção semi circular a um perfil HEA 360.
#
# a) Enuncie o teorema dos eixos paralelos aplicado a momentos de inércia de superfícies.
#
# b) Utilizando as informações que constam da tabela anexa, e aplicando o teorema dos eixos paralelos, determine os momentos de inércia da secção transversal em relação aos eixos x e y do referencial cuja origem coincide com o centroide da secção.
#
# c) Diga o que entende por eixos principais de inércia de uma superfície. Indique, justificando, se os eixos x, y do referencial representado são eixos principais de inércia para a secção transversal dada.
#
# <img src="https://userweb.fct.unl.pt/~jmc.xavier//MAI/Notebooks/Ch06/P4/MAI_Ch06_P4.png"
# width="600">
#
# ### Resolução

# %% [markdown]
# ---
#
# Copyright (c) DEMI - FCT NOVA
#
# Interactive computing by <a href="https://jupyter.org/" target="_blank"> <span
# style="color:#333399"> Jupyter Notebook </span> </a> &nbsp;|&nbsp;Coded by <a href = "mailto: jmc.xavier@fct.unl.pt">José Xavier</a>
#
# Licensed under  <a href="http://creativecommons.org/licenses/by-sa/4.0/"
# target="_blank"> <span style="color:#333399;font-size: 20px"> CC BY-SA 4.0  </span></a>
