# %% [markdown]
# <img src="https://userweb.fct.unl.pt/~jmc.xavier/MAI/iLogos/logo_novafct.png" width="200">
#
# # Departamento de Engenharia Mecânica e Industrial
# ## Mecânica Aplicada I

# %% [markdown]
# ## Força e momento de uma força
# ### Problema 2
#
#
# Três forças atuam em A como se indica na figura, de forma a equilibrar um vaso. Determine o vetor resultante das forças representadas, sabendo que a magnitude das mesmas é: $F_{AB} = 1308~N$, $F_{AC} = 763$ N, $F_{AD} = 708,5$ N  para $x = 2$ m e $z = 1,5$ m.
#
# <img src="https://userweb.fct.unl.pt/~jmc.xavier/MAI/Notebooks/Ch01/P2/MAI_Ch01_P2.png"
# width="800"/>

# %%
import numpy as np
from numpy import array, sqrt, dot
FAB, FAC, FAD = 1308, 763, 708.5
A = (0,0,0)
C = (2,-6,3)
D = (-2,-6,1.5)

FABy = FAB

vecAC = array(C) - array(A)
normAC = sqrt(dot(vecAC,vecAC))
print(f'AC: vetor = {vecAC} | norma = {normAC} ')
versAC = vecAC/normAC
print(f'AC: versor = {versAC}')
compFAC = FAC*versAC
print(f'FAC (S0xyz): vetor = {compFAC}')
# Out:
# AC: vetor = [ 2 -6  3] | norma = 7.0
# AC: versor = [ 0.28571429 -0.85714286  0.42857143]
# FAC (S0xyz): vetor = [ 218. -654.  327.]

# %%
vecAD = array(D) - array(A)
normAD = sqrt(dot(vecAD,vecAD))
print(f'AD: vetor = {vecAD} | norma = {normAD} ')
versAD = vecAD/normAD
print(f'AD: versor = {versAD}')
compFAD = FAD*versAD
print(f'FAD (S0xyz): vetor = {compFAD}')
# Out:
# AD: vetor = [-2.  -6.   1.5] | norma = 6.5
# AD: versor = [-0.30769231 -0.92307692  0.23076923]
# FAD (S0xyz): vetor = [-218.  -654.   163.5]

# %%
Rx = compFAC[0] + compFAD[0]
Ry = FABy + compFAC[1] + compFAD[1]
Rz = compFAC[2] + compFAD[2]
R = sqrt(Rx ** 2 + Ry ** 2 + Rz ** 2)
print(f' R: vetor = {Rx, Ry, Rz} N')
print(f' R: norma = {R:.1f} N')
# Out:
#  R: vetor = (0.0, 0.0, 490.5) N
#  R: norma = 490.5 N

# %% [markdown]
# <img src="https://userweb.fct.unl.pt/~jmc.xavier/MAI/Notebooks/Ch01/P2/MAI_Ch01_P2_2b.png"
# width="800"/>

# %% [markdown]
# # Anexo
#
# - Escolha de um referencial cartesiano associado ao ponto A;
# - Exprimir os vetores em função das suas componentes do referêncial escolhido;
#
# $\vec{AC}$
#
# - pontos do segmento de recta:
#
# $A(0,0,0)\quad\wedge\quad C(2,-6,3)$
#
# \begin{equation*}
# \vec{AC} = \vec{OC} - \vec{OA}  = (2,-6,3) = 2\vec{i} -6\vec{j} + 3\vec{k}
# \end{equation*}
#
# - Norma euclidiana de um vetor,
#
# \begin{equation*}
# ||\vec{AC}|| = \sqrt{\vec{AC} \cdot \vec{AC}}
# = \sqrt{x_{AC}^2 + y_{AC}^2 + z_{AC}^2}
# \end{equation*}
#
# - Versor do vetor $\vec{AC}$,
#
# \begin{equation*}
# \vec{\lambda}_{AC} = \frac{\vec{AC}}{||\vec{AC}||}
# \end{equation*}
#
# - Definição do produco interno ou produto escalar de dois vetores,
#
# \begin{equation*}
# \vec{a}\cdot\vec{b} = |a| |b| \cos\angle(\vec{a},\vec{b})
# \quad\therefore\quad \vec{a}\cdot\vec{a} = a²
# \end{equation*}
#
# - Cálculo matricial do produto interno ou escalar de dois vetores,
#
# \begin{equation*}
# \vec{a}\cdot\vec{b} = \sum_{i=1}^n a_i b_i = \{a\}^T \{b\}
# \end{equation*}

# %% [markdown]
# ---
#
# Copyright (c) DEMI - FCT NOVA
#
# Interactive computing by <a href="https://jupyter.org/" target="_blank"> <span
# style="color:#333399"> Jupyter Notebook </span> </a> &nbsp;|&nbsp;Coded by <a href = "mailto: jmc.xavier@fct.unl.pt">José Xavier</a>
#
# Licensed under  <a href="http://creativecommons.org/licenses/by-sa/4.0/"
# target="_blank"> <span style="color:#333399;font-size: 20px"> CC BY-SA 4.0  </span></a>
