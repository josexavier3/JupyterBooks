# %% [markdown]
# <img src="https://userweb.fct.unl.pt/~jmc.xavier/MAI/iLogos/logo_novafct.png" width="200">
#
# # Departamento de Engenharia Mecânica e Industrial
# ## Mecânica Aplicada I

# %% [markdown]
# #### Problema 11
#
# A figura representa uma chapa com 250x400 mm, com 15 kg de massa e uma roldana com 300 mm de diâmetro, soldadas a um veio AD, que se apoia nas chumaceiras A e
# B.  Considere o ângulo $\beta = 30^\circ$ e também que a chumaceira B não exerce reação segundo o eixo $z$. Considere que a roldana é um disco fino com 2,5 kg de massa e determine o momento de inércia do conjunto placa e roldana em relação ao eixo z.
#
# <img src="https://userweb.fct.unl.pt/~jmc.xavier/MAI/Notebooks/Ch06/Au7_P11.png"
# style="max-width: 100%;"/>
# ***
#
# #### Resumo
#
# **Momentos de Inércia**
#
# <img src="https://userweb.fct.unl.pt/~jmc.xavier/MAI/Notebooks/Ch05/FormMomInercia01.jpg"
# style="max-width: 100%;"/>
#
# <img src="https://userweb.fct.unl.pt/~jmc.xavier/MAI/Notebooks/Ch05/FormMomInercia02.jpg"
# style="max-width: 100%;"/>
#
# <img src="https://userweb.fct.unl.pt/~jmc.xavier/MAI/Notebooks/Ch05/FormMomInercia03.jpg"
# style="max-width: 100%;"/>
#
# #### Resolução

# %% [markdown]
# ---
#
# Copyright (c) DEMI - FCT NOVA
#
# Interactive computing by <a href="https://jupyter.org/" target="_blank"> <span
# style="color:#333399"> Jupyter Notebook </span> </a> &nbsp;|&nbsp;Coded by <a href = "mailto: jmc.xavier@fct.unl.pt">José Xavier</a>
#
# Licensed under  <a href="http://creativecommons.org/licenses/by-sa/4.0/"
# target="_blank"> <span style="color:#333399;font-size: 20px"> CC BY-SA 4.0  </span></a>
