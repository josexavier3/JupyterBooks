# %% [markdown]
# <img src="https://userweb.fct.unl.pt/~jmc.xavier/MAI/iLogos/logo_novafct.png" width="200">
#
# # Departamento de Engenharia Mecânica e Industrial
# ## Mecânica Aplicada I

# %% [markdown]
# <img src="https://drive.google.com/uc?id=1UdlzYpbgZ5H3nzyDxxDoZIvOnZd2c46j"
# alt="DEMI" width="400" height="130">
#
# ## Mecânica Aplicada I | DEMI | FCT | UNL
# Link para a página oficial da Unidade Curricular <a
# href="https://guia.unl.pt/pt/2020/fct/program/982/course/10576#general-characterization"
# class="nounderline"
# target="_blank" rel="noopener"><span style="color:#333399; font-family: Lucida
# Sans; font-size: 9pt; font-style: none; font-weight: bold"> <img
# src="https://userweb.fct.unl.pt/~jmc.xavier/MAI/iLogos/link002.png"
# height="13"></span> </a>
#
# <a href="https://jupyter.org/" class="nounderline" target="_blank"
# rel="noopener"><span
# style="color:#333399; font-family: Lucida Sans; font-size: 9pt; font-style:
# none; font-weight: bold"> <img
# src="https://userweb.fct.unl.pt/~jmc.xavier/MAI/iLogos/link.png" height="16">
# </span> </a> &nbsp;_Interactive computing by Jupyter Notebook | Coded by_ [<span
# style="color:#78866B; font-family: Lucida Sans; font-size: 11pt; font-style:
# italic; font-weight: bold"> _José Xavier_ </span>](mailto:jmc.xavier@fct.unl.pt)
#
# ## EQUILÍBRIO DA PARTÍCULA NO PLANO
#
# ***
# #### Problema 5
#
# No plano vertical, uma carga de peso 400 N é suspensa por um cabo AB e dois cabos ACF e ADE que passando pelas roldanas C e D são presos a blocos de pesos 3W e W, respetivamente. Considere que na posição ilustrada o sistema está em equilíbrio estático.
#
# <img src="https://drive.google.com/uc?id=1AM06wXxEGg8z22lNkQwIw9_QJ5doaRAz"
# style="max-width: 100%;"/>
#
#
# a)	Diga o que entende por um diagrama de corpo livre.
#
# b)	Apresente os seguintes diagramas de corpo livre:
#
# b.1) do conjunto dos cabos definido pela linha FCADE.
#
# b.2) do ponto A.
#
# c)	Calcule a intensidade do peso W e da força instalada no cabo AB.
# ***
#
# #### Resolução

# %% [markdown]
# ---
#
# Copyright (c) [Mecânica Aplicada - DEMI - FCT NOVA]
#
# Interactive computing by <a href="https://jupyter.org/" target="_blank"> <span
# style="color:#333399"> Jupyter Notebook </span> </a> &nbsp;|&nbsp;Coded by <a href = "mailto: jmc.xavier@fct.unl.pt">José Xavier</a>
#
# Licensed under  <a href="http://creativecommons.org/licenses/by-sa/4.0/"
# target="_blank"> <span style="color:#333399;font-size: 20px"> CC BY-SA 4.0  </span></a>
