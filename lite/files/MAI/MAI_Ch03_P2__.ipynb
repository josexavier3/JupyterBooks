# %% [markdown]
# <img src="https://userweb.fct.unl.pt/~jmc.xavier/MAI/iLogos/logo_novafct.png" width="200">
#
# # Departamento de Engenharia Mecânica e Industrial
# ## Mecânica Aplicada I

# %% [markdown]
# <img src="https://drive.google.com/uc?id=1UdlzYpbgZ5H3nzyDxxDoZIvOnZd2c46j"
# alt="DEMI" width="400" height="130">
#
# ## Mecânica Aplicada I | DEMI | NOVA-SST | UNL
# <a href="https://guia.unl.pt/pt/2020/fct/program/982/course/10576#general
# -characterization"
# class="nounderline"
# target="_blank" rel="noopener"><span style="color:#333399; font-family: Lucida
# Sans; font-size: 9pt; font-style: none; font-weight: bold">  Link </a>
# para a página oficial da Unidade Curricular
#
# Interactive computing by
# <a href="https://jupyter.org/" class="nounderline" target="_blank"
# rel="noopener"><span
# style="color:#333399; font-family: Lucida Sans; font-size: 9pt; font-style:
# none; font-weight: bold"> Jupyter Notebook </a> &nbsp;_| Coded by_ [<span
# style="color:#78866B; font-family: Lucida Sans; font-size: 11pt; font-style:
# italic; font-weight: bold"> _José Xavier_ </span>](mailto:jmc.xavier@fct.unl.pt)
#
#
# ## EQUILÍBRIO DO CORPO RÍGIDO NO PLANO. ATRITO.
#
# ***
# #### Problema 2
#
# A extremidade A de uma barra delgada e uniforme de comprimento $L$ e peso $\vec{P}$ apoia-se sobre uma superfície horizontal, enquanto a ponta B está presa a um cabo BC, como se ilustra na figura. Os coeficientes de atrito são $\mu_c = $ 0,25 e $\mu_c = $ 0,35. Determine o maior valor de $\theta$ compatível com o equilíbrio e o correspondente valor da tração no cabo.
#
# <img src="https://drive.google.com/uc?id=1-mTn8cfOO8ZFILfjpcardrCcF4XAYZLZ"
# style="max-width: 100%;"/>
# ***
# #### Resolução

# %% [markdown]
# ---
#
# Copyright (c) DEMI - FCT NOVA
#
# Interactive computing by <a href="https://jupyter.org/" target="_blank"> <span
# style="color:#333399"> Jupyter Notebook </span> </a> &nbsp;|&nbsp;Coded by <a href = "mailto: jmc.xavier@fct.unl.pt">José Xavier</a>
#
# Licensed under  <a href="http://creativecommons.org/licenses/by-sa/4.0/"
# target="_blank"> <span style="color:#333399;font-size: 20px"> CC BY-SA 4.0  </span></a>
