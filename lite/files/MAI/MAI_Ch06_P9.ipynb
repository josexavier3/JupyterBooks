# %% [markdown]
# <img src="https://userweb.fct.unl.pt/~jmc.xavier/MAI/iLogos/logo_novafct.png" width="200">
#
# # Departamento de Engenharia Mecânica e Industrial
# ## Mecânica Aplicada I

# %% [markdown]
# ## MOMENTO DE 2ª ORDEM DE UMA SUPERFÍCIE. MOMENTO DE INÉRCIA DE UM CORPO.
#
# ### Problema 10
#
# Considere a superfície plana da figura.
#
# **a)** Calcule o momento de inércia da superfície relativamente ao eixo $x$.
#
# **b)**	Sem efetuar cálculos, explique o significado físico do produto de inércia desta superfície relativamente ao referencial $S(0, x, y)$.
#
# <img src="https://userweb.fct.unl.pt/~jmc.xavier/MAI/Notebooks/Ch05/P9/MAI_Ch05_P9.png"
# style="max-width: 100%;"/>
#
# ### Resumo
#
# **Momentos de Inércia**
#
# <img src="https://userweb.fct.unl.pt/~jmc.xavier/MAI/Notebooks/GFormulas/FormMomInercia01.jpg"
# style="max-width: 100%;"/>
#
# <img src="https://userweb.fct.unl.pt/~jmc.xavier/MAI/Notebooks/GFormulas/FormMomInercia02.jpg"
# style="max-width: 100%;"/>
#
# <img src="https://userweb.fct.unl.pt/~jmc.xavier/MAI/Notebooks/GFormulas/FormMomInercia03.jpg"
# style="max-width: 100%;"/>
#
# #### Resolução

# %% [markdown]
# ---
#
# Copyright (c) DEMI - FCT NOVA
#
# Interactive computing by <a href="https://jupyter.org/" target="_blank"> <span
# style="color:#333399"> Jupyter Notebook </span> </a> &nbsp;|&nbsp;Coded by <a href = "mailto: jmc.xavier@fct.unl.pt">José Xavier</a>
#
# Licensed under  <a href="http://creativecommons.org/licenses/by-sa/4.0/"
# target="_blank"> <span style="color:#333399;font-size: 20px"> CC BY-SA 4.0  </span></a>
