# %% [markdown]
# <img src="https://userweb.fct.unl.pt/~jmc.xavier/MAI/iLogos/logo_novafct.png" width="200">
#
# # Departamento de Engenharia Mecânica e Industrial
# ## Mecânica Aplicada I

# %% [markdown]
# ## MOMENTO DE 2ª ORDEM DE UMA SUPERFÍCIE. MOMENTO DE INÉRCIA DE UM CORPO.
#
# ### Problema 10
#
# Considere a superfície plana com $a=3$ mm.
#
# a) Calcule o momento de 2ª ordem da superfície relativamente ao eixo $y$.
#
# b) Calcule as coordenadas ($\overline{x} , \overline{y}$) do centroide da superfície para o referencial indicado.
#
# c) Calcule o momento de 2ª ordem da superfície relativamente ao eixo baricêntrico $y’$ paralelo ao eixo $y$.
#
# d) Explique, sem efetuar cálculos, quais são os eixos principais centrais deinércia da superfície plana representada.
#
# <img src="https://userweb.fct.unl.pt/~jmc.xavier/MAI/Notebooks/Ch05/P10/MAI_Ch06_P10.png"
# style="max-width: 100%;"/>
#
# ### Resumo
#
# **Momentos de Inércia**
#
# <img src="https://userweb.fct.unl.pt/~jmc.xavier/MAI/Notebooks/Ch05/FormMomInercia01.jpg"
# style="max-width: 100%;"/>
#
# <img src="https://userweb.fct.unl.pt/~jmc.xavier/MAI/Notebooks/Ch05/FormMomInercia02.jpg"
# style="max-width: 100%;"/>
#
# <img src="https://userweb.fct.unl.pt/~jmc.xavier/MAI/Notebooks/Ch05/FormMomInercia03.jpg"
# style="max-width: 100%;"/>
#
# #### Resolução

# %% [markdown]
# ---
#
# Copyright (c) DEMI - FCT NOVA
#
# Interactive computing by <a href="https://jupyter.org/" target="_blank"> <span
# style="color:#333399"> Jupyter Notebook </span> </a> &nbsp;|&nbsp;Coded by <a href = "mailto: jmc.xavier@fct.unl.pt">José Xavier</a>
#
# Licensed under  <a href="http://creativecommons.org/licenses/by-sa/4.0/"
# target="_blank"> <span style="color:#333399;font-size: 20px"> CC BY-SA 4.0  </span></a>
